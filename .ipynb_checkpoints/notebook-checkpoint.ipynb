# %%
# %pylab inline 
import cv2, time
from IPython.display import clear_output
import dlib
import tensorflow as tf

# import Image
from skimage import io
from PIL import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
vid = cv2.VideoCapture(0)
try:
    while(True):
        
        start = time.time()
        ret, frame = vid.read()
        if not ret:
            vid.release()
            break
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.flip(frame, 1 )
#       
        imshow(frame)
        show()
        clear_output(wait=True)
        #time.sleep(2.0)
except KeyboardInterrupt:
    vid.release()
    print("Released Video Resource")
# Out:
# Released Video Resource

# %%
type(frame)
# Out:
# numpy.ndarray

# %%
plt.imshow(frame)

# %%
def detect_face(image):
    face_detector = dlib.get_frontal_face_detector()
    detected_faces = face_detector(image, 1)
    face_frames = [(x.left(), x.top(),
                    x.right(), x.bottom()) for x in detected_faces]
    return face_frames

# %%
detected_face = detect_face(frame)

#Crop
for n, face_rect in enumerate(detected_face):
    face = Image.fromarray(frame).crop(face_rect)

# %%
plt.imshow(face)

# %%
#convert opencv
open_cv_image = np.array(face)

# %%
open_cv_image.shape
# Out:
# (185, 186, 3)

# %%
plt.imshow(open_cv_image)

# %%
open_cv_image = cv2.resize(open_cv_image, (160,160)).reshape((1,160,160,3))

# %%
def load_graph(frozen_graph_filename):
    with tf.gfile.GFile(frozen_graph_filename, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def, name="")
    return graph

# %%
frozen_graph="./in-res/in-res.pb"
graph = load_graph(frozen_graph)

# %%
# for op in graph.get_operations():
#     print(op.name)

# %%
from dlib_utils import extract_left_eye_center, extract_right_eye_center, get_rotation_matrix, crop_image

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
dets = detector(frame, 1)

# %%
# https://github.com/nlhkh/face-alignment-dlib/blob/master/app.py

# %%
x = graph.get_tensor_by_name('input:0')
phase_train_placeholder = graph.get_tensor_by_name('phase_train:0')
y = graph.get_tensor_by_name('embeddings:0')

# %%
with tf.Session(graph=graph) as sess:
    features = sess.run(y, feed_dict={x:open_cv_image, phase_train_placeholder:False})

# %%
features = np.squeeze(features).reshape(-1,128)

# %%
test = features

# %%
# train_m = features

# %%
# train_v = features

# %%
d_test_m = np.linalg.norm(test-train_m)
d_test_m

# %%
d_test_v = np.linalg.norm(test-train_v)
d_test_v

# %%
#Inception

# %%
tl = './inception_pb/inception.pb'
graph4 = load_graph(tl)

# %%
# for op in graph4.get_operations():
#     print(op.name)

# %%
#Get nodes
x = graph4.get_tensor_by_name('ExpandDims:0')
y = graph4.get_tensor_by_name('pool_3:0')

# %%
frame_m = cv2.imread('./data/midhun.png')
frame_m = cv2.cvtColor(frame_m, cv2.COLOR_BGR2RGB)
plt.imshow(frame_m)

# %%
open_cv_image = cv2.resize(frame_m, (299,299)).reshape((1,299,299,3))

# %%
with tf.Session(graph=graph4) as sess:
    features = sess.run(y, feed_dict={x:open_cv_image})

# %%
# en_midhun = features

# %%
# en_vivek = features

# %%
np.linalg.norm(en_midhun-en_vivek)
# Out:
# 11.313104

# %%
#Create test encoding

# %%
detected_face = detect_face(frame)

#Crop
for n, face_rect in enumerate(detected_face):
    face = Image.fromarray(frame).crop(face_rect)

# %%
plt.imshow(face)

# %%
open_cv_image = np.array(face)
open_cv_image = cv2.resize(open_cv_image, (299,299)).reshape((1,299,299,3))

# %%
with tf.Session(graph=graph4) as sess:
    features = sess.run(y, feed_dict={x:open_cv_image})

# %%
en_test = features

# %%
np.linalg.norm(en_test - en_vivek)
# Out:
# 13.770292

# %%
np.linalg.norm(en_test - en_midhun)
# Out:
# 13.384613

# %%
def decode(value):
    if value == 1:
        val = 'person-1'
        return val
    if value == 7:
        val = 'person-2'
        return val
    else:
        val = 'unknown person'
        return val

# %%
d = decode(y_predict)

# %%
print(d)

# %%
plt.imshow(frame)
# plt.title(d)

# %%
# Load image
img_path = 'test.jpg'
image = io.imread(img_path)

# Detect faces
detected_faces = detect_faces(image)

# Crop faces and plot
for n, face_rect in enumerate(detected_faces):
    face = Image.fromarray(image).crop(face_rect)
    plt.subplot(1, len(detected_faces), n+1)
    plt.axis('off')
    plt.imshow(face)
